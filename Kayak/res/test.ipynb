# %%
import pandas as pd

dataset = pd.read_json("Hotels.json")

# %%
dataset
# Out:
#                                                   name  \
# 0      \nSéjours & Affaires Aix-en-Provence Mirabeau\n
# 1                                    \nHôtel Vendôme\n
# 2                                      \nLe Concorde\n
# 3                                  \nHôtel Le Mozart\n
# 4                                   \nHotel des Arts\n
# ..                                                 ...
# 145  \nT2 classé 3 étoile au centre du quartier his...
# 146                       \nCardeur Furnished studio\n
# 147  \nCharming studio in the historic district in ...
# 148  \nCosy studio in the centre of Aix-en-Provence...
# 149  \nLumineux Aix Plein Centre avec Parking Gratu...
#
#                                                    url  \
# 0    https://www.booking.com\n/hotel/fr/residence-m...
# 1    https://www.booking.com\n/hotel/fr/ha-tel-vend...
# 2    https://www.booking.com\n/hotel/fr/le-concorde...
# 3    https://www.booking.com\n/hotel/fr/le-mozart.f...
# ...
